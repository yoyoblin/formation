# %% [markdown]
# ## Mémo pour la mise en forme d'un Notebook
# <h1 style="width:100%;text-align:center;">Markdown pour les nuls !</h1>

# %% [markdown]
# -Insérer un TITRE en gros

# %% [markdown]
# # Titre

# %% [markdown]
# -Insérer un sous-titre

# %% [markdown]
# ## sous-titre

# %% [markdown]
# -Insérer du texte en gras

# %% [markdown]
# **en gras**

# %% [markdown]
# -Insérer un TITRE en italique

# %% [markdown]
# _en italique_

# %% [markdown]
# Insérer du texte souligné

# %% [markdown]
# <u> IMPORTANT </u>

# %% [markdown]
# -Insérer un lien hypertexte

# %% [markdown]
# https://ellasciences.jimdofree.com/

# %% [markdown]
# -Insérer des puces ( * et espace )

# %% [markdown]
# *
# *

# %% [markdown]
# -Insérer un cadre

# %% [markdown]
# <div style="border: thick double orange; padding:10px">
# Mes remarques sur le point précédent</div>

# %% [markdown]
# <h3 style="border:3px solid DodgerBlue;">
#
#     OBJECTIFS: Ecrire plusieurs scripts calculant la Force d'attraction gravitationnelle exercée par différentes planètes sur un astronaute (vous)
#
# </h3>

# %% [markdown]
# -Insérer du texte en couleur

# %% [markdown]
# <font color="red" > IMPORTANT </font>

# %% [markdown]
# -Insérer un cadre en couleur

# %% [markdown]
# <div style="background-color: ##f2e6ff;">
# Enregistrez votre travail et revenez pour voir votre note et mes observations
# </div>

# %% [markdown]
# -Insérer un texte qui est dévoilé

# %% [markdown]
# <details>
# <summary>Une petite AIDE ? Alors clique içi !  </summary>
# Tu dois penser à .... </details>

# %% [markdown]
# -Insérer une image

# %% [markdown]
# <img src="https://longstreet.typepad.com/.a/6a00d83542d51e69e20192aae81fe2970d-pi" data-align="center" />

# %% [markdown]
# -Insérer une image liée

# %% [markdown]
# <a href="https://www.yout-ube.com/watch?v=UYE9Do3-5XE"><img src="attachment:screenshot.4661.jpg"></a> </center>

# %% [markdown]
# -Insérer une animation Geogébra ( partager ds geogebra puis insertion et enfin copier le code iframe )

# %%
from IPython.display import HTML
HTML("""<iframe src="https://www.geogebra.org/classic/xwvfx23y?embed" width="800" height="600" allowfullscreen style="border: 1px solid #e4e4e4;border-radius: 4px;" frameborder="0"></iframe>""")
# Out:
# <iframe src="https://www.geogebra.org/classic/xwvfx23y?embed" width="800" height="600" allowfullscreen style="border: 1px solid #e4e4e4;border-radius: 4px;" frameborder="0"></iframe>

# %% [markdown]
# -Insérer une vidéo

# %%
from IPython.display import HTML
HTML("""<iframe width="706" height="397" src="https://www.youtube.com/embed/KuQ20SECCUk" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>""")
# Out:
# <iframe width="706" height="397" src="https://www.youtube.com/embed/KuQ20SECCUk" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
