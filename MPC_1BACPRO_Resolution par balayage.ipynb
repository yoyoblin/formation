# %% [markdown]
# # <span style="color:orange"> Cherchez une solution à une équation de type f(x) = 0 par balayage

# %% [markdown]
# ___
# >###  <span style="color:blue">Astuce n°1 : Dans l'onglet *Affichage* --> *Affichez les numéros de lignes*
# >### <span style="color:purple">Astuce n°2 : Exécutez une cellule et cliquez sur `>Exécuter` ou bien sur `MAJ + ENTER`
# >### <span style="color:red"> N'oubliez pas d'enregistrer souvent vos travaux !!!
# ___
# ![interface%20-%20Moyenne.jpeg](attachment:interface%20-%20Moyenne.jpeg)

# %% [markdown]
# ## <span style="color:green"> >>> Coup de pouce :
# ### <span style="color:green"> - On définit une fonction en premier dans un programme. Dans l'exemple ci-dessous, la fonction carré est étudiée sur l'intervalle [0;5]

# %%
def f(x) :
    return x**2     # le carré est obtenu avec **

for x in range(0,6):
    print(x,"-->",f(x))
# Out:
# 0 --> 0
# 1 --> 1
# 2 --> 4
# 3 --> 9
# 4 --> 16
# 5 --> 25

# %% [markdown]
# ## <span style="color:orange"> PARTIE 1 : Trouver un encadrement de la solution à 0,1 près
# > ### - Complétez et testez le programme. Voici l'expression de la fonction  qui permet de modéliser la trajectoire :  $$f(x) = -0,06\times x^{2}+0,85\times x+2$$

# %% [markdown]
# ![adapter%20-%20Petite.jpeg](attachment:adapter%20-%20Petite.jpeg)

# %%
# ecrivez la fonction après return
def f(x) :
    return 

# valeur de départ
x = 0 

while f(x) > 0 :
    x = x + 0.1

# affiche l'encadrement
print ("entre",x-0.1,"et",x)
# Out:
# Traceback (most recent call last):
#   File "<input>", line 8, in <module>
# TypeError: '>' not supported between instances of 'NoneType' and 'int'
# Error:

# %% [markdown]
# ___
# ___
#
# ## <span style="color:orange"> PARTIE 2 : créez un programme pour trouver un encadrement à 0.01 près de la solution
#
# > ### - Donnez la solution sur votre feuille
# > ### - Améliorez le programme en arrondissant les valeurs affichée avec `round(x,0.001)`

# %% [markdown]
# ![cre%CC%81er%20-%20Petite.jpeg](attachment:cre%CC%81er%20-%20Petite.jpeg)

# %% [markdown]
# ___
# ___
#
# ## <span style="color:orange"> PARTIE 3 : vérifiez votre résultat avec la cellule graphique
#
# > ### - Vous pouvez déplacer et zoomer dans le graphique
# > ### - Grace à la lecture des coordonnées qui apparraissent près du curseur de souris, validez votre résultat.

# %% [markdown]
# ![valider%20-%20Petite.jpeg](attachment:valider%20-%20Petite.jpeg)

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.clf() # efface la mémoire graphique

x = np.linspace(0,18,20)
y = -0.06*x**2+0.85*x+2
plt.plot(x,y)          

plt.axis([0,18,0,7]) # repère mini/maxi
plt.ylabel("axe des ordonnées")
plt.xlabel("axe des abcisses")
plt.grid()
plt.show()
