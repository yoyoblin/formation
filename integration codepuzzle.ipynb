# %% [markdown]
# ## Apprentissage de la boucle `for` avec une suite arithmétique

# %% [markdown]
# ### 1. Utilisez le jeu de puzzle de code ci-dessous :
# > ####  Placez les lignes dans le bon ordre
# > ####  Respectez l'indentation de la boucle
# > ####  Vérifiez votre puzzle

# %%
import IPython.display as display
puzzle = """<iframe width="100%" height="500" src="https://www.codepuzzle.io/p/VA93"></iframe>"""
display.HTML(puzzle)
# Out:
# <iframe width="100%" height="500" src="https://www.codepuzzle.io/p/VA93"></iframe>

# %% [markdown]
# ### 2. Expérimentez et recopiez le programme dans la zone de code ci-dessous :

# %% [markdown]
# ### 3. Inspirez vous du programme ci-dessus pour en créer un autre qui affichera les termes de la suite :
#
# > #### Suite arithmétique de premier terme u1 = 12 et de raison 4.5
# > #### Affichez 20 termes et leur numérotation
