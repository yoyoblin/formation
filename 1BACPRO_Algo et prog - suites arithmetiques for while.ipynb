# %% [markdown]
# # <span style="color:red"> Algorithme et programmation : les suites arithmétiques

# %% [markdown]
# ### Dans les activités suivantes il vous sera demandé d'interprèter les algorithmes suivants sous la forme de programmes en python

# %% [markdown]
# ___
# ### <span style="color:blue"> 1. La boucle "répète n fois" est traduite en python par `for` avec la syntaxe suivante :

# %% [markdown]
# ![algo_f02%20-%20Petite.jpeg](attachment:algo_f02%20-%20Petite.jpeg)

# %%
u = 27
for n in range(1,11) :  # la variable n est un compteur qui prend toutes les numéros de 1 à 10
    print(u)
    u = u + 19
# Out:
# 27
# 46
# 65
# 84
# 103
# 122
# 141
# 160
# 179
# 198

# %% [markdown]
# > ### Créez un programme d'apprès l'algorithme suivant :
#  ici on a rajouté une numérotation avec la variable n

# %% [markdown]
# ![algo_f03%20-%20Petite.jpeg](attachment:algo_f03%20-%20Petite.jpeg)

# %% [markdown]
# ___
# ### <span style="color:blue"> 2. La boucle "tant que" est traduite en python par `while` avec la syntaxe suivante :

# %% [markdown]
# ![algo_w01%20-%20Petite.jpeg](attachment:algo_w01%20-%20Petite.jpeg)

# %%
u = 10
while u <= 100 :
    print (u)
    u = u+8     # si vous oubliez la ligne 4 vous créez une boucle infinie
# Out:
# 10
# 18
# 26
# 34
# 42
# 50
# 58
# 66
# 74
# 82
# 90
# 98

# %% [markdown]
# > ### Modifiez le programme d'apprès l'algorithme suivant :
#  ici on a rajouté une numérotation avec la variable n, cette variable **doit être créée et ensuite augmentée à chaque tour de boucle**

# %% [markdown]
# ![algo_w02%20-%20Petite.jpeg](attachment:algo_w02%20-%20Petite.jpeg)

# %%
u = 1
n = 1      # il est nécéssaire de créer la variable compteur
while u <=   :
    print (u)
    u = u+
    n = n+1
