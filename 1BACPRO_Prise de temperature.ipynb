# %% [markdown]
# # Algorithme prise de température d'un nourisson

# %% [markdown]
# ### 1. Voici le protocole professionnel que vous devez transformer en programme : voir fiche élève

# %% [markdown]
# #### Prise de température corporelle axillaire chez le nouveau-né : Conduite à tenir si la température est perturbée.
#
# > **Si valeur inférieure à 36,5 °C :** (Confirmer la mesure avec une prise par voie rectale)
#
# >> - **Si valeur < 36,5°C mais > 36,0 °C** proposer le peau à peau avec la mère ou couvrir le bébé. Si valeur non normalisée au bout de 1-2 heures, appeler le Pédiatre de garde
# >> - **Si valeurs < 35,9 °C**, appeler le Pédiatre de garde.
#
# > **Si valeur supérieure à 37,5°C** (Confirmer la mesure avec une prise par voie rectale)
#
# >> - **Si valeur > 37,5°C mais < 38°C**, enlever une pièce de vêtement (la brassière)/ changer le pyjama par un autre plus fin ou découvrir le bébé. Si valeur non normalisée au bout de 1-2 heures, appeler le pédiatre de garde.
# >> - **Si valeur ≥ 38,0 °C**, appeler le pédiatre de garde.

# %% [markdown]
# ### 2. Programme à adapter/modifier :

# %% [markdown]
# > - **Complétez** les phrases et **testez** le programme pour les températures données sur la fiche.
# > - **Il existe un bug** ...à vous de le corriger

# %%
t = float(input("temperature de bébé ?"))

if t < 36 :
	print("phrase 1")

elif 36 <= t < 36.5 :
	print("phrase 2")

elif 37.5 < t < 38 :
	print("phrase 3")

elif t > 38 :
	print("phrase 4")

else :
	print("phrase 5")
# Out:
# temperature de bébé ?38
# phrase 4
