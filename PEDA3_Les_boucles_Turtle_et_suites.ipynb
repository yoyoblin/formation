# %% [markdown]
# # **PEDA3 Les boucles, le module turtle et les suites**

# %% [markdown]
# - **Boucle bornée :** Quand on sait combien de fois doit avoir lieu la répétition, on utilise généralement une boucle **FOR**
#
# - **Boucle non bornée :** si on ne connait pas à l'avance le nombre de répétitions on choisit une boucle **WHILE**

# %% [markdown]
# ## **Défi n°1 :** Créer des boucles bornées et non bornées
# ---

# %% [markdown]
# 1.   Observez le programme suivant. Que va t'il afficher ?
# 2.   Comment modifier ce programme pour qu'il affiche les trois premiers nombres pairs ?

# %%
x = 0
while x < 5 :
  print(x)
  x = x + 1
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# 3.   Que fait le programme suivant ?

# %%
for i in range (5,15,3) :
  print(i)

# %% [markdown]
# 4.   Complétez le programme pour obtenir la somme des 100 premiers entiers naturels

# %%
s = 0
for i in range () :
  s = s + i
print()

# %% [markdown]
# ## **Défi n°2 :** Dessiner avec des boucles-turtle
# ---

# %% [markdown]
# 1. Observez le programme suivant. Que va t'il afficher ?
# 2. Comment modifier ce programme pour qu'il affiche un triangle équilatéral de
#  100 pixels de côté?

# %%
from turtle import *

for i in range(4) :
  forward(50)
  left(90)

done()

# %% [markdown]
# 3. Compléter le programme permettant de tracer un hexagone de pixel 100 ayant
# des côtés de couleurs différentes (rouge, vert, bleu, orange, jaune, gris)

# %%
from turtle import *

for i in ["red",] : # liste de couleurs
  forward()
  left()

done()

# %% [markdown]
# 4. Observez le programme suivant. Que va t'il afficher ?

# %%
from turtle import *

i = 0     # initialisation obligatoire de la variable compteur
while i < 6 : # liste de couleurs
  forward(100)
  left(60)
  i = i + 1

done()

# %% [markdown]
# ## **Défi n°3 :** Suites et boucles : while ou for ?
# ---

# %% [markdown]
# #### Problème n°1 : Pour préparer une compétition de course à pied, Lisa s'entraîne de façon progressive. Elle commence par courir 4 km et augmente chaque jour la distance de 50 m.
#
# **- Complétez le programme suivant permettant :**
# > - d'obtenir les distances parcourues chaque jour, pendant 4 semaines.
# > - d'obtenir la distance totale parcourue, en km, après 4 semaines.

# %%
n = 
Un =

for n :
  Un = 4 + (n-1)* 0.050
  print("U",n,"=",Un)
  S = 

Print("S =",)

# %% [markdown]
# #### Problème n°2 : Au 1er janvier 2020, la concentration d'algues vertes dans un bassin est de 102 mg/L. En y introduisant des jacinthes d'eau, cette concentration diminue alors tousles mois de 3 %. On estime que l'objectif est atteint quand la concentration en algues vertes est strictement inférieure à 80 mg/L.
# 1. **Complétez** le programme suivant pour qu'il affiche le nombre de mois nécessaires afin d'atteindre l'objectif indiqué.
# 2. **Ajoutez** un élément permettant d'obtenir les résultats arrondis à deux décimales près.

# %%
n = 
u =

........n > ............ :
  n =
  u = 
  print(,n,u)

# %% [markdown]
# ## **Défi n°4 :** while ET for
# ---

# %% [markdown]
# #### Problème n°3 : Soit une suite définie par : $$Un=\frac{n^{3}}{n+5}$$

# %% [markdown]
# 1. **Complétez** le programme suivant permettant de demander une valeur de n et d'afficher la valeur de Un correspondante.

# %%
n = int (......("valeur de n"))  # entrée de la valeur n
Un =
                                 # Affichage de Un

# %% [markdown]
# 2. **Créez un programme plus complet** pour qu'il affiche les 500 premiers termes.

# %% [markdown]
# 3. **Créez un autre programme** pour qu'il retrouve la valeur de n à partir de laquelle Un > 500 000
