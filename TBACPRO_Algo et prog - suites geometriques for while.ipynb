# %% [markdown]
# # <span style="color:red"> Algorithme et programmation : les suites arithmétiques

# %% [markdown]
# ### Dans les activités suivantes il vous sera demandé d'interprèter les algorithmes suivants sous la forme de programmes en python

# %% [markdown]
# ___
# ### <span style="color:blue"> 1. La boucle "répète n fois" est traduite en python par `for` avec la syntaxe suivante :

# %% [markdown]
# ![algo2_01%20-%20Petite.jpeg](attachment:algo2_01%20-%20Petite.jpeg)

# %%
u = 100
for n in range(1,7) :  # la variable n est un compteur qui prend toutes les numéros de 1 à 6
    print(u)
    u = u*2
# Out:
# 100
# 200
# 400
# 800
# 1600
# 3200

# %% [markdown]
# > ### Créez un programme d'apprès l'algorithme suivant :
#  ici on a rajouté une numérotation avec la variable n --
#  **utilisez `print(n,u)`**

# %% [markdown]
# ![algo2_02%20-%20Petite.jpeg](attachment:algo2_02%20-%20Petite.jpeg)

# %% [markdown]
# ___
# ### <span style="color:blue"> 2. La boucle "tant que" est traduite en python par `while` avec la syntaxe suivante :

# %% [markdown]
# ![algo2_04%20-%20Petite.jpeg](attachment:algo2_04%20-%20Petite.jpeg)

# %%
u = 10
while u <= 500 :
    print (u)
    u = u*3    # si vous oubliez la ligne 4 vous créez une boucle infinie
# Out:
# 10
# 30
# 90
# 270

# %% [markdown]
# > ### Modifiez le programme d'apprès l'algorithme suivant :
#  ici on a rajouté une numérotation avec la variable n, cette variable **doit être créée et ensuite augmentée à chaque tour de boucle**  **utilisez `print(n,u)`**

# %% [markdown]
# ![algo2_03%20-%20Petite.jpeg](attachment:algo2_03%20-%20Petite.jpeg)

# %%
u = 
n = 1      # il est nécéssaire de créer la variable compteur
while u <=    :
    print (u)
    u = u*
    n = n+1
# Out:
#   File "<input>", line 1
#     u =
#        ^
# SyntaxError: invalid syntax
