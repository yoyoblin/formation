# %% [markdown]
# ## <span style="color:red"> PYFICHE SUITES02 : Les boucles for et while <span>

# %% [markdown]
# >####  <span style="color:green">Astuce n°1 : Dans l'onglet *Affichage* --> *Affichez les numéros de lignes*
# >#### <span style="color:green">Astuce n°2 : Selectionnez une cellule et cliquez sur *>Run* ou bien sur MAJ + ENTER
# >#### <span style="color:green"> N'oubliez pas d'enregistrer souvent vos travaux

# %% [markdown]
# ---
# ### <span style="color:orange">Objectif n°1 : l'échéancier du contrat <span>
#
# > **Rappel de l'énoncé :**
# >![voiture%20-%20Petite.jpeg](attachment:voiture%20-%20Petite.jpeg)
# >Offre de 24 mois et 10000 Km annuel, premier loyer de 1 584,26€, suivi de 23 autres loyers mensuels de 89,26€ (hors assurance).
# >> #### Vous devez écrire un programme pour afficher l’échéancier de ce contrat.
# >> ####  <span style="color:green">Astuce n°1 : Coup de pouce sur la boucle `for`

# %%
for n in range (1,6):
    print(n)           # instruction indentée
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# > **Ecrivez votre programme ci-dessous :**

# %% [markdown]
# ---
# ### <span style="color:orange">Objectif n°2 : ne pas dépasser 5000€ <span>
#
# > **Rappel de l'énoncé :**
# >Au bout de combien de mois la somme de 5000€ serait elle atteinte ?
# >> **Complétez le programme suivant pour répondre à cette question**

# %%
u=
n=
while u  :
    print(n,u)
    u = u +
    n = n+1
